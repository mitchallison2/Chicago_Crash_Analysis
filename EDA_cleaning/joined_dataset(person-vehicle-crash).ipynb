# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, FunctionTransformer
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer,  make_column_selector as selector
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import plot_confusion_matrix, recall_score,\
    accuracy_score, precision_score, f1_score

from sklearn.dummy import DummyClassifier

from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImPipeline

from sklearn.multioutput import MultiOutputClassifier

import pickle

# %%
unpickleFile = open('./Data/clean_people.pkl', 'rb')
people_df = pickle.load(unpickleFile, encoding='bytes')
people_df.head()
# Out:
#   PERSON_ID                                    CRASH_RECORD_ID  VEHICLE_ID  \
# 0   O749947  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...    834816.0
# 1   O871921  af84fb5c8d996fcd3aefd36593c3a02e6e7509eeb27568...    827212.0
# 2    O10018  71162af7bf22799b776547132ebf134b5b438dcf3dac6b...      9579.0
# 3    O10038  c21c476e2ccc41af550b5d858d22aaac4ffc88745a1700...      9598.0
# 4    O10039  eb390a4c8e114c69488f5fb8a097fe629f5a92fd528cf4...      9600.0
#
#   DRIVERS_LICENSE_CLASS SEX   AGE  SAFETY_EQUIPMENT
# 0                     D   M  25.0      NONE PRESENT
# 1                   NaN   M  37.0  SAFETY BELT USED
# 2                   NaN   X   NaN     USAGE UNKNOWN
# 3                   NaN   X   NaN     USAGE UNKNOWN
# 4                   NaN   X   NaN     USAGE UNKNOWN

# %%
unpickleFile = open('./Data/clean_vehicles.pkl', 'rb')
vehicle_df = pickle.load(unpickleFile, encoding='bytes')
vehicle_df.head()
# Out:
#                                      CRASH_RECORD_ID  VEHICLE_ID UNIT_TYPE  \
# 0  24ddf9fd8542199d832e1c223cc474e5601b356f1d77a6...    796949.0    DRIVER
# 1  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...    834816.0    DRIVER
# 2  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...    834819.0    PARKED
# 3  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...    834817.0    PARKED
# 4  af84fb5c8d996fcd3aefd36593c3a02e6e7509eeb27568...    827212.0    DRIVER
#
#    NUM_PASSENGERS                              MAKE    MODEL VEHICLE_DEFECT  \
# 0             0.0                          INFINITI  UNKNOWN           NONE
# 1             0.0                             HONDA    CIVIC        UNKNOWN
# 2             0.0                            TOYOTA    YARIS           NONE
# 3             0.0  GENERAL MOTORS CORPORATION (GMC)   SIERRA        UNKNOWN
# 4             0.0                             BUICK   ENCORE           NONE
#
#   VEHICLE_TYPE VEHICLE_USE        MANEUVER FIRST_CONTACT_POINT
# 0    PASSENGER    PERSONAL  STRAIGHT AHEAD               FRONT
# 1    PASSENGER    PERSONAL  STRAIGHT AHEAD               FRONT
# 2   UNKNOWN/NA    PERSONAL          PARKED                ROOF
# 3   UNKNOWN/NA  UNKNOWN/NA          PARKED                ROOF
# 4    PASSENGER    PERSONAL  STRAIGHT AHEAD         FRONT-RIGHT

# %%
unpickleFile = open('./Data/clean_crashes.pkl', 'rb')
crash_df = pickle.load(unpickleFile, encoding='bytes')
crash_df.head()
# Out:
#                                      CRASH_RECORD_ID  POSTED_SPEED_LIMIT  \
# 0  0115ade9a755e835255508463f7e9c4a9a0b47e9304238...                  30
# 1  017040c61958d2fa977c956b2bd2d6759ef7754496dc96...                  30
# 2  01aaa759c6bbefd0f584226fbd88bdc549de3ed1e46255...                  40
# 3  0362b3f8ddb8589dfe889356efbc2ad213efe2031556f0...                  30
# 4  03d3679ef44bb8aa0f2060cb0376f3eeb1d9dbb2197322...                  30
#
#   WEATHER_CONDITION      LIGHTING_CONDITION FIRST_CRASH_TYPE  \
# 0             CLEAR  DARKNESS, LIGHTED ROAD            ANGLE
# 1             CLEAR                DAYLIGHT         REAR END
# 2   CLOUDY/OVERCAST                DAYLIGHT            ANGLE
# 3              RAIN                DAYLIGHT         REAR END
# 4              RAIN                DAYLIGHT       PEDESTRIAN
#
#                    TRAFFICWAY_TYPE           ALIGNMENT ROADWAY_SURFACE_COND  \
# 0                      NOT DIVIDED  STRAIGHT AND LEVEL                  DRY
# 1                      NOT DIVIDED  STRAIGHT AND LEVEL                  DRY
# 2       DIVIDED - W/MEDIAN BARRIER  STRAIGHT AND LEVEL                  DRY
# 3  DIVIDED - W/MEDIAN (NOT RAISED)  STRAIGHT AND LEVEL                  WET
# 4                         FOUR WAY  STRAIGHT AND LEVEL                  WET
#
#   ROAD_DEFECT                        CRASH_TYPE  \
# 0     UNKNOWN            NO INJURY / DRIVE AWAY
# 1  NO DEFECTS            NO INJURY / DRIVE AWAY
# 2  NO DEFECTS            NO INJURY / DRIVE AWAY
# 3  NO DEFECTS            NO INJURY / DRIVE AWAY
# 4  NO DEFECTS  INJURY AND / OR TOW DUE TO CRASH
#
#          PRIM_CONTRIBUTORY_CAUSE SEC_CONTRIBUTORY_CAUSE STREET_DIRECTION  \
# 0            UNABLE TO DETERMINE    UNABLE TO DETERMINE                N
# 1            UNABLE TO DETERMINE    UNABLE TO DETERMINE                N
# 2            IMPROPER LANE USAGE         NOT APPLICABLE                N
# 3            UNABLE TO DETERMINE    UNABLE TO DETERMINE                N
# 4  FAILING TO YIELD RIGHT-OF-WAY    UNABLE TO DETERMINE                S
#
#    BEAT_OF_OCCURRENCE  CRASH_HOUR  CRASH_DAY_OF_WEEK  CRASH_MONTH INJURY_LEVEL
# 0              1123.0           0                  6            7            0
# 1              1811.0          18                  6            7            0
# 2              2024.0          17                  6            7            0
# 3              1634.0           8                  6            7            0
# 4              1235.0          16                  6            7            1

# %% [markdown]
# # Goal
#
# My goal here is to create a df that contains a row for every driver of a crash.
#
# This row will contain unique info about the driver and vehicle they were driving. There will be duplicates of the crash condition data for each person/vehicle, as this data will apply to multiple drivers if there were multiple driven cars involved in the crash.

# %%
driver_vehicle = pd.DataFrame()

# %%
vehicle_df.drop(columns=['CRASH_RECORD_ID'], inplace=True)

# %%
# Create df of driver and vehicle for every driver
driver_vehicle = people_df.join(vehicle_df.set_index('VEHICLE_ID'),
                               on = 'VEHICLE_ID',
                               how = 'left')

# %%
driver_vehicle.head()
# Out:
#   PERSON_ID                                    CRASH_RECORD_ID  VEHICLE_ID  \
# 0   O749947  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...    834816.0
# 1   O871921  af84fb5c8d996fcd3aefd36593c3a02e6e7509eeb27568...    827212.0
# 2    O10018  71162af7bf22799b776547132ebf134b5b438dcf3dac6b...      9579.0
# 3    O10038  c21c476e2ccc41af550b5d858d22aaac4ffc88745a1700...      9598.0
# 4    O10039  eb390a4c8e114c69488f5fb8a097fe629f5a92fd528cf4...      9600.0
#
#   DRIVERS_LICENSE_CLASS SEX   AGE  SAFETY_EQUIPMENT UNIT_TYPE  NUM_PASSENGERS  \
# 0                     D   M  25.0      NONE PRESENT    DRIVER             0.0
# 1                   NaN   M  37.0  SAFETY BELT USED    DRIVER             0.0
# 2                   NaN   X   NaN     USAGE UNKNOWN    DRIVER             0.0
# 3                   NaN   X   NaN     USAGE UNKNOWN    DRIVER             0.0
# 4                   NaN   X   NaN     USAGE UNKNOWN    DRIVER             0.0
#
#       MAKE    MODEL VEHICLE_DEFECT VEHICLE_TYPE VEHICLE_USE        MANEUVER  \
# 0    HONDA    CIVIC        UNKNOWN    PASSENGER    PERSONAL  STRAIGHT AHEAD
# 1    BUICK   ENCORE           NONE    PASSENGER    PERSONAL  STRAIGHT AHEAD
# 2  UNKNOWN  UNKNOWN           NONE    PASSENGER    PERSONAL         BACKING
# 3  UNKNOWN  UNKNOWN        UNKNOWN   UNKNOWN/NA  UNKNOWN/NA      UNKNOWN/NA
# 4  UNKNOWN  UNKNOWN        UNKNOWN   UNKNOWN/NA  UNKNOWN/NA      UNKNOWN/NA
#
#   FIRST_CONTACT_POINT
# 0               FRONT
# 1         FRONT-RIGHT
# 2                REAR
# 3             UNKNOWN
# 4             UNKNOWN

# %%
# drop unneccesary cols
driver_vehicle.drop(columns=['VEHICLE_ID', 'PERSON_ID'], inplace=True)
driver_vehicle.head()
# Out:
#                                      CRASH_RECORD_ID DRIVERS_LICENSE_CLASS  \
# 0  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...                     D
# 1  af84fb5c8d996fcd3aefd36593c3a02e6e7509eeb27568...                   NaN
# 2  71162af7bf22799b776547132ebf134b5b438dcf3dac6b...                   NaN
# 3  c21c476e2ccc41af550b5d858d22aaac4ffc88745a1700...                   NaN
# 4  eb390a4c8e114c69488f5fb8a097fe629f5a92fd528cf4...                   NaN
#
#   SEX   AGE  SAFETY_EQUIPMENT UNIT_TYPE  NUM_PASSENGERS     MAKE    MODEL  \
# 0   M  25.0      NONE PRESENT    DRIVER             0.0    HONDA    CIVIC
# 1   M  37.0  SAFETY BELT USED    DRIVER             0.0    BUICK   ENCORE
# 2   X   NaN     USAGE UNKNOWN    DRIVER             0.0  UNKNOWN  UNKNOWN
# 3   X   NaN     USAGE UNKNOWN    DRIVER             0.0  UNKNOWN  UNKNOWN
# 4   X   NaN     USAGE UNKNOWN    DRIVER             0.0  UNKNOWN  UNKNOWN
#
#   VEHICLE_DEFECT VEHICLE_TYPE VEHICLE_USE        MANEUVER FIRST_CONTACT_POINT
# 0        UNKNOWN    PASSENGER    PERSONAL  STRAIGHT AHEAD               FRONT
# 1           NONE    PASSENGER    PERSONAL  STRAIGHT AHEAD         FRONT-RIGHT
# 2           NONE    PASSENGER    PERSONAL         BACKING                REAR
# 3        UNKNOWN   UNKNOWN/NA  UNKNOWN/NA      UNKNOWN/NA             UNKNOWN
# 4        UNKNOWN   UNKNOWN/NA  UNKNOWN/NA      UNKNOWN/NA             UNKNOWN

# %%
driver_vehicle.shape
# Out:
# (1121892, 14)

# %%
dv_crash = pd.DataFrame()

# %%
# Create df of driver+vehicle for every driver, with crash info
dv_crash = driver_vehicle.join(crash_df.set_index('CRASH_RECORD_ID'),
                               on = 'CRASH_RECORD_ID',
                               how = 'left')

# %%
dv_crash.head()
# Out:
#                                      CRASH_RECORD_ID DRIVERS_LICENSE_CLASS  \
# 0  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...                     D
# 1  af84fb5c8d996fcd3aefd36593c3a02e6e7509eeb27568...                   NaN
# 2  71162af7bf22799b776547132ebf134b5b438dcf3dac6b...                   NaN
# 3  c21c476e2ccc41af550b5d858d22aaac4ffc88745a1700...                   NaN
# 4  eb390a4c8e114c69488f5fb8a097fe629f5a92fd528cf4...                   NaN
#
#   SEX   AGE  SAFETY_EQUIPMENT UNIT_TYPE  NUM_PASSENGERS     MAKE    MODEL  \
# 0   M  25.0      NONE PRESENT    DRIVER             0.0    HONDA    CIVIC
# 1   M  37.0  SAFETY BELT USED    DRIVER             0.0    BUICK   ENCORE
# 2   X   NaN     USAGE UNKNOWN    DRIVER             0.0  UNKNOWN  UNKNOWN
# 3   X   NaN     USAGE UNKNOWN    DRIVER             0.0  UNKNOWN  UNKNOWN
# 4   X   NaN     USAGE UNKNOWN    DRIVER             0.0  UNKNOWN  UNKNOWN
#
#   VEHICLE_DEFECT  ... ROAD_DEFECT              CRASH_TYPE  \
# 0        UNKNOWN  ...  NO DEFECTS  NO INJURY / DRIVE AWAY
# 1           NONE  ...  NO DEFECTS  NO INJURY / DRIVE AWAY
# 2           NONE  ...  NO DEFECTS  NO INJURY / DRIVE AWAY
# 3        UNKNOWN  ...  NO DEFECTS  NO INJURY / DRIVE AWAY
# 4        UNKNOWN  ...  NO DEFECTS  NO INJURY / DRIVE AWAY
#
#                PRIM_CONTRIBUTORY_CAUSE  \
# 0                  UNABLE TO DETERMINE
# 1          IMPROPER OVERTAKING/PASSING
# 2  DRIVING SKILLS/KNOWLEDGE/EXPERIENCE
# 3                  UNABLE TO DETERMINE
# 4                  UNABLE TO DETERMINE
#
#                    SEC_CONTRIBUTORY_CAUSE  STREET_DIRECTION  \
# 0                          NOT APPLICABLE                 N
# 1  FAILING TO REDUCE SPEED TO AVOID CRASH                 W
# 2                          NOT APPLICABLE                 W
# 3                     UNABLE TO DETERMINE                 N
# 4                          NOT APPLICABLE                 S
#
#   BEAT_OF_OCCURRENCE CRASH_HOUR CRASH_DAY_OF_WEEK CRASH_MONTH INJURY_LEVEL
# 0             1531.0        3.0               7.0         9.0            0
# 1              613.0       22.0               2.0         4.0            0
# 2              821.0        5.0               1.0        11.0            0
# 3             2023.0        8.0               1.0        11.0            0
# 4              223.0       10.0               1.0        11.0            0
#
# [5 rows x 31 columns]

# %%
# drop unneccary cols
dv_crash.drop(columns=['CRASH_RECORD_ID'], inplace=True)

# %%
dv_crash.shape
# Out:
# (1121892, 30)

# %% [markdown]
# # Some additional cleaning

# %%
dv_crash.isna().sum()
# Out:
# DRIVERS_LICENSE_CLASS      415017
# SEX                             0
# AGE                        296536
# SAFETY_EQUIPMENT                0
# UNIT_TYPE                   33172
# NUM_PASSENGERS              33172
# MAKE                        33172
# MODEL                       33172
# VEHICLE_DEFECT              33172
# VEHICLE_TYPE                33172
# VEHICLE_USE                 33172
# MANEUVER                    33172
# FIRST_CONTACT_POINT         33172
# POSTED_SPEED_LIMIT            598
# WEATHER_CONDITION             598
# LIGHTING_CONDITION            598
# FIRST_CRASH_TYPE              598
# TRAFFICWAY_TYPE               598
# ALIGNMENT                     598
# ROADWAY_SURFACE_COND          598
# ROAD_DEFECT                   598
# CRASH_TYPE                    598
# PRIM_CONTRIBUTORY_CAUSE       598
# SEC_CONTRIBUTORY_CAUSE        598
# STREET_DIRECTION              598
# BEAT_OF_OCCURRENCE            598
# CRASH_HOUR                    598
# CRASH_DAY_OF_WEEK             598
# CRASH_MONTH                   598
# INJURY_LEVEL                  598
# dtype: int64

# %%
# Drop 598 rows that are missing speed limit, weather condition, etc
dv_crash.dropna(subset=['POSTED_SPEED_LIMIT'], inplace=True)
dv_crash.isna().sum()
# Out:
# DRIVERS_LICENSE_CLASS      414774
# SEX                             0
# AGE                        296379
# SAFETY_EQUIPMENT                0
# UNIT_TYPE                   33148
# NUM_PASSENGERS              33148
# MAKE                        33148
# MODEL                       33148
# VEHICLE_DEFECT              33148
# VEHICLE_TYPE                33148
# VEHICLE_USE                 33148
# MANEUVER                    33148
# FIRST_CONTACT_POINT         33148
# POSTED_SPEED_LIMIT              0
# WEATHER_CONDITION               0
# LIGHTING_CONDITION              0
# FIRST_CRASH_TYPE                0
# TRAFFICWAY_TYPE                 0
# ALIGNMENT                       0
# ROADWAY_SURFACE_COND            0
# ROAD_DEFECT                     0
# CRASH_TYPE                      0
# PRIM_CONTRIBUTORY_CAUSE         0
# SEC_CONTRIBUTORY_CAUSE          0
# STREET_DIRECTION                0
# BEAT_OF_OCCURRENCE              0
# CRASH_HOUR                      0
# CRASH_DAY_OF_WEEK               0
# CRASH_MONTH                     0
# INJURY_LEVEL                    0
# dtype: int64

# %%
dv_crash.shape
# Out:
# (1121294, 30)

# %%
# We'll go ahead and drop the rows that are missing UNIT_TYPE, etc as well. We're only losing about 3% of our data
# Considering that these are all missing the same data, they likely have an explanation.
# This data isn't very easily imputed, etc for missing values as well(most common vehicle type? etc)
# dv_crash[dv_crash['UNIT_TYPE'].isna()]
dv_crash.dropna(subset=['UNIT_TYPE'], inplace=True)
dv_crash.isna().sum()
# Out:
# DRIVERS_LICENSE_CLASS      388727
# SEX                             0
# AGE                        291805
# SAFETY_EQUIPMENT                0
# UNIT_TYPE                       0
# NUM_PASSENGERS                  0
# MAKE                            0
# MODEL                           0
# VEHICLE_DEFECT                  0
# VEHICLE_TYPE                    0
# VEHICLE_USE                     0
# MANEUVER                        0
# FIRST_CONTACT_POINT             0
# POSTED_SPEED_LIMIT              0
# WEATHER_CONDITION               0
# LIGHTING_CONDITION              0
# FIRST_CRASH_TYPE                0
# TRAFFICWAY_TYPE                 0
# ALIGNMENT                       0
# ROADWAY_SURFACE_COND            0
# ROAD_DEFECT                     0
# CRASH_TYPE                      0
# PRIM_CONTRIBUTORY_CAUSE         0
# SEC_CONTRIBUTORY_CAUSE          0
# STREET_DIRECTION                0
# BEAT_OF_OCCURRENCE              0
# CRASH_HOUR                      0
# CRASH_DAY_OF_WEEK               0
# CRASH_MONTH                     0
# INJURY_LEVEL                    0
# dtype: int64

# %% [markdown]
# Now we have a 'clean' dataset that achieves our goals. We'll pickle this DataFrame and re-examine our FSM model next.

# %%
dv_crash.to_pickle("./Data/clean_joined_df.pkl")
